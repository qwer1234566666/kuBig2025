# %%
bream_length = [
    25.4,
    26.3,
    26.5,
    29.0,
    29.0,
    29.7,
    29.7,
    30.0,
    30.0,
    30.7,
    31.0,
    31.0,
    31.5,
    32.0,
    32.0,
    32.0,
    33.0,
    33.0,
    33.5,
    33.5,
    34.0,
    34.0,
    34.5,
    35.0,
    35.0,
    35.0,
    35.0,
    36.0,
    36.0,
    37.0,
    38.5,
    38.5,
    39.5,
    41.0,
    41.0,
]
bream_weight = [
    242.0,
    290.0,
    340.0,
    363.0,
    430.0,
    450.0,
    500.0,
    390.0,
    450.0,
    500.0,
    475.0,
    500.0,
    500.0,
    340.0,
    600.0,
    600.0,
    700.0,
    700.0,
    610.0,
    650.0,
    575.0,
    685.0,
    620.0,
    680.0,
    700.0,
    725.0,
    720.0,
    714.0,
    850.0,
    1000.0,
    920.0,
    955.0,
    925.0,
    975.0,
    950.0,
]

# %%
import matplotlib.pyplot as plt

plt.scatter(bream_length, bream_weight)
plt.xlabel("length(cm)")
plt.ylabel("weight(g)")
plt.show()

# %%
smelt_length = [
    9.8,
    10.5,
    10.6,
    11.0,
    11.2,
    11.3,
    11.8,
    11.8,
    12.0,
    12.2,
    12.4,
    13.0,
    14.3,
    15.0,
]
smelt_weight = [
    6.7,
    7.5,
    7.0,
    9.7,
    9.8,
    8.7,
    10.0,
    9.9,
    9.8,
    12.2,
    13.4,
    12.2,
    19.7,
    19.9,
]

# %%
import matplotlib.pyplot as plt

plt.scatter(bream_length, bream_weight)
plt.scatter(smelt_length, smelt_weight)
plt.xlabel("length(cm)")
plt.ylabel("weight(g)")
plt.show()

# %%
length = bream_length + smelt_length
weight = bream_length + smelt_weight
fish_data = [[l, w] for l, w in zip(length, weight)]
fish_label = [1] * len(bream_length) + [0] * len(smelt_length)
for data, label in zip(fish_data, fish_label):
    print(f"DATA : {data}, LABEL : {label}")
# Out:
# DATA : [25.4, 25.4], LABEL : 1
# DATA : [26.3, 26.3], LABEL : 1
# DATA : [26.5, 26.5], LABEL : 1
# DATA : [29.0, 29.0], LABEL : 1
# DATA : [29.0, 29.0], LABEL : 1
# DATA : [29.7, 29.7], LABEL : 1
# DATA : [29.7, 29.7], LABEL : 1
# DATA : [30.0, 30.0], LABEL : 1
# DATA : [30.0, 30.0], LABEL : 1
# DATA : [30.7, 30.7], LABEL : 1
# DATA : [31.0, 31.0], LABEL : 1
# DATA : [31.0, 31.0], LABEL : 1
# DATA : [31.5, 31.5], LABEL : 1
# DATA : [32.0, 32.0], LABEL : 1
# DATA : [32.0, 32.0], LABEL : 1
# DATA : [32.0, 32.0], LABEL : 1
# DATA : [33.0, 33.0], LABEL : 1
# DATA : [33.0, 33.0], LABEL : 1
# DATA : [33.5, 33.5], LABEL : 1
# DATA : [33.5, 33.5], LABEL : 1
# DATA : [34.0, 34.0], LABEL : 1
# DATA : [34.0, 34.0], LABEL : 1
# DATA : [34.5, 34.5], LABEL : 1
# DATA : [35.0, 35.0], LABEL : 1
# DATA : [35.0, 35.0], LABEL : 1
# DATA : [35.0, 35.0], LABEL : 1
# DATA : [35.0, 35.0], LABEL : 1
# DATA : [36.0, 36.0], LABEL : 1
# DATA : [36.0, 36.0], LABEL : 1
# DATA : [37.0, 37.0], LABEL : 1
# DATA : [38.5, 38.5], LABEL : 1
# DATA : [38.5, 38.5], LABEL : 1
# DATA : [39.5, 39.5], LABEL : 1
# DATA : [41.0, 41.0], LABEL : 1
# DATA : [41.0, 41.0], LABEL : 1
# DATA : [9.8, 6.7], LABEL : 0
# DATA : [10.5, 7.5], LABEL : 0
# DATA : [10.6, 7.0], LABEL : 0
# DATA : [11.0, 9.7], LABEL : 0
# DATA : [11.2, 9.8], LABEL : 0
# DATA : [11.3, 8.7], LABEL : 0
# DATA : [11.8, 10.0], LABEL : 0
# DATA : [11.8, 9.9], LABEL : 0
# DATA : [12.0, 9.8], LABEL : 0
# DATA : [12.2, 12.2], LABEL : 0
# DATA : [12.4, 13.4], LABEL : 0
# DATA : [13.0, 12.2], LABEL : 0
# DATA : [14.3, 19.7], LABEL : 0
# DATA : [15.0, 19.9], LABEL : 0

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/yjh/.local/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/yjh/.local/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/yjh/.local/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/yjh/.local/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/yjh/.local/lib/python3.10/site-packages (from scikit-learn) (1.15.3)

# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

fish_data = np.array(fish_data)
kn = KNeighborsClassifier()
kn.fit(fish_data, fish_label)
# Out:
# KNeighborsClassifier()

# %%
kn.score(fish_data, fish_label)
# Out:
# 1.0

# %%
kn.predict(np.array([[20.0, 300.0], [13.0, 20.0]]))
# Out:
# array([1, 0])
